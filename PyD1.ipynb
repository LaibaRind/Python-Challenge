# %%
name:str="Laiba Anwer"
f_message:str=f"""Hello,
Python Learners!
I'm {name}.🚀 Today is the
first step in our coding journey."""
print(f_message)
# Out:
# Hello,
# Python Learners!
# I'm Laiba Anwer.🚀 Today is the
# first step in our coding journey.
